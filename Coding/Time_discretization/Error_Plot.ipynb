# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([0.1,0.2,0.3,0.4], [1340,1010,690,470])

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0.75, 1.00,1.25,1.50,1.75,2.00,2.25,2.50,2.75,3.00])
ypoints = np.array([3.51,1.25,4.45,2.56,4.18,1.21,4.1,2.48,4.42,1.32])

plt.plot(xpoints, ypoints, 'o')
plt.xticks(np.arange(min(xpoints), max(xpoints)+0.25, 0.25))
plt.yticks(np.arange(min(ypoints), max(ypoints)+0.2, 0.4))
font1 = {'family':'serif','color':'black','size':15}
# plt.title("Numerical Solution",fontdict = font1)
plt.xlabel('Aspect Ratio(a/b)',fontdict = font1)
plt.ylabel('Buckling Amplitude(m)',fontdict = font1)
plt.show()

# %%
x = [0,5,9,10,15]
y = [0,1,2,3,4]
plt.plot(x,y)
plt.xticks(np.arange(min(x), max(x)+1, 2))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

x = [0,5,9,10,15]
y = [0,1,2,3,4]
fig, ax = plt.subplots()
ax.plot(x,y)
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 0.712123))
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%0.1f'))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, math.pi*2, 0.05)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
y = np.sin(x)
ax.plot(x, y)
ax.set_xlabel('angle')
ax.set_title('sine')
ax.set_xticks([0,2,4,6])
ax.set_xticklabels(['zero','two','four','six'])
ax.set_yticks([-1,0,1])
plt.show()

# %%
import matplotlib.pyplot as plt

number_of_element = [ 10,20,40,60,100,200,300,400]
Error_comsol = [ 4.37e-9,3.1e-10,3.0e-11,1.0e-11,1.0e-11,1.0e-11,1.0e-11,1.0e-11]
Error_ngsolve = [ 4.71e-9,2.99e-10,1.88e-11,3.67e-12,4.61e-13,5.74e-14,5.74e-14,5.74e-14]
ax= plt.subplot()
plt.yscale("log")
plt.xscale("log")
plt.plot(number_of_element,Error_comsol,color='black',label='  Error comsol',linestyle="-")
plt.plot(number_of_element,Error_ngsolve,color='black',label=' Error NgSolve ',linestyle=":")
plt.legend()
plt.xlabel("log(N)")
plt.ylabel("log(E)")
# Out:
# Text(0, 0.5, 'log(E)')
