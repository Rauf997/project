# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
plt.plot([0.1,0.2,0.3,0.4], [1340,1010,690,470])

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0.75, ])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()
