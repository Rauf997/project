# %%
import matplotlib.pyplot as plt

# %%
x = [ 150, 200, 250, 300,350,400,450,500,550,600,650 ]
y_1 = [ 42.125,23.704,15.173,10.538,7.742,5.928,4.684,3.794,3.135,2.635,2.245 ]
# y_2 = [ 116.232,65.436,41.901,29.107,21.398,16.378,12.942,10.484,8.665,7.2818,6.205]
plt.plot(x, y_1, color="black", marker="o",  linestyle="-", label ='1st mode')
# plt.plot(x, y_2, color="black", marker="o",  linestyle="-",label ='2nd mode')
plt.legend()
plt.xlabel("Radius[$\mu$ m]")
plt.ylabel("Critical Stress[MPa]")
# Out:
# Text(0, 0.5, 'Critical Stress[MPa]')

# %%
x = [ 1, 1.2, 1.4, 1.6,1.8,2.0,2.2,2.4,2.6]
y_1 = [ 1.482,2.134,2.905,3.794,4.801,5.928,7.172,8.536,10.018 ]
# y_2 = [ 4.097,5.898,8.027,10.484,13.268,16.378,19.816,23.358,27.767]
plt.plot(x, y_1, color="Black", marker="o",  linestyle="-", label ='1st mode')
# plt.plot(x, y_2, color="black", marker="o",  linestyle="-",label ='2nd mode')
plt.legend()
plt.xlabel("Thickness[$\mu$ m]")
plt.ylabel("Critical Stress[MPa]")
# Out:
# Text(0, 0.5, 'Critical Stress[MPa]')

# %%
x = [ 1, 1.2, 1.4, 1.6,1.8,2.0,2.2,2.4,2.6]
y_1 = [ 1.5975,2.760,4.383,6.542,9.315,12.777,17.005,22.076,28.067 ]
y_2 = [ 3.078,5.319,8.445,12.605,17.946,24.615,32.758,42.524,54.060]
plt.plot(x, y_1, color="red", marker="o",  linestyle="-", label ='1st mode')
plt.plot(x, y_2, color="black", marker="o",  linestyle="-",label ='2nd mode')
plt.legend()
plt.xlabel("Thickness[$\mu$ m]")
plt.ylabel("Critical Stress[MPa]")
# Out:
# Text(0, 0.5, 'Critical Stress[MPa]')

# %%
x = [ 265.80,354.4,443.0,531.6,620.2,708.80,797.40,886.00,974.6,1063.20,1151.80]
y_1 = [ 90.75,51.07,32.69,22.71,16.68,12.77,10.09,8.17,6.75,5.67,4.83]
y_2 = [ 174.56,98.32,62.96,43.74,32.14,24.61,19.45,15.75,13.02,10.94,9.32]
plt.plot(x, y_1, color="red", marker="o",  linestyle="-", label ='1st mode')
plt.plot(x, y_2, color="black", marker="o",  linestyle="-",label ='2nd mode')
plt.legend()
plt.xlabel("Area[$\mu$ m]")
plt.ylabel("Critical Stress[MPa]")
# Out:
# Text(0, 0.5, 'Critical Stress[MPa]')
