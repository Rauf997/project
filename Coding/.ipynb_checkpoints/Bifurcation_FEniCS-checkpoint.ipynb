# %%
from fenics import *
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
import numpy as np

# %%
mesh = UnitIntervalMesh(50)

# %%
V = FunctionSpace(mesh, "Lagrange", 1)

# %%
u = Function(V)
v = TestFunction(V)
lambd = Constant(1.0)

# %%
bc = DirichletBC(V,0.0,"on_boundary")

# %%
F = inner(grad(u),grad(v))*dx - lambd**2*sin(u)*v*dx

# %%
u.interpolate(Expression("-sin(2*pi*x[0])", degree = 2))
u_mid = np.zeros(15)
plot(u)

# %%
for ij, lambd_val in enumerate(list(np.linspace(0, 2*pi, 15))):
    lambd.assign(lambd_val)
    lambd = Constant(lambd_val)
    F = inner(grad(u),grad(v))*dx - lambd**2*sin(u)*v*dx
    solve(F==0, u, bc, solver_parameters={"newton_solver": {"maximum_iterations": 100}})
    u_mid[ij]=u(0.5)
    plot(u)
# Out:
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.416e+01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton iteration 1: r (abs) = 8.226e-14 (tol = 1.000e-10) r (rel) = 9.774e-16 (tol = 1.000e-09)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.226e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.224e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.222e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.219e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.216e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.212e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.209e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.205e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.202e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.200e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.200e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.201e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.205e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.212e-14 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#   Newton solver finished in 0 iterations and 0 linear solver iterations.

# %%
lambd
# Out:
# Coefficient(FunctionSpace(None, FiniteElement('Real', None, 0)), 198)

# %%
u_mid
# Out:
# array([-3.44169138e-15, -3.44169138e-15, -3.44169138e-15, -3.44169138e-15,
#        -3.44169138e-15, -3.44169138e-15, -3.44169138e-15, -3.44169138e-15,
#        -3.44169138e-15, -3.44169138e-15, -3.44169138e-15, -3.44169138e-15,
#        -3.44169138e-15, -3.44169138e-15, -3.44169138e-15])

# %%
u(0.5)
# Out:
# -3.4416913763379853e-15

# %%
plot(u)
